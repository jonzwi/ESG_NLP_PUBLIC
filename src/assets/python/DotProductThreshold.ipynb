# %%
import pandas as pd
pd.set_option('max_colwidth', 50)

import numpy as np
import ast
import json
import os

### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

# if not 'cleanURL.py' in os.listdir():
#   cleanURL_PY = '1WFCzNdHClqA2f8n8-82Vbq_0tjInh65w'

#   !gdown $cleanURL_PY

#   from cleanURL import cleanURL


# ### AMZN data
# URL_E = '/content/sample_data/formatted_NVDA_10K_E.csv'
# URL_S = '/content/sample_data/formatted_NVDA_10K_S.csv'
# URL_G = '/content/sample_data/formatted_NVDA_10K_G.csv'

company = "DHR"

URL_E = "src/assets/Formatted_Data/formatted_{}_10K_E.csv".format(company)
URL_S = "src/assets/Formatted_Data/formatted_{}_10K_S.csv".format(company)
URL_G = "src/assets/Formatted_Data/formatted_{}_10K_G.csv".format(company)

output_pth = "public/Formatted_Threshold/formatted_{}_10K_".format(company)


os.chdir("C:/Users/jleckron/ReactProjects/esgnlpfrontend")


### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

def main(LIST_URLS, topN=50):

  E,S,G = LIST_URLS

  df_E = pd.read_csv(E)
  df_S = pd.read_csv(S)
  df_G = pd.read_csv(G)

  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 


  def sentimentElection(df, rowNum, categoryESG, electionMode='balanced'):

    if categoryESG not in ['E','S','G']:
      print(f'categoryESG must be "E", "S", or "G"' )
      return


    maxSentimentCols = [ col for col in df.columns if 'maxSentiment' in col ]
    modelSentiments  = []

    for col in maxSentimentCols:
      modelSentiments.append( df[col][rowNum] )
    
    tally = sorted({ k:modelSentiments.count(k) for k in set(modelSentiments) }.items(), reverse=True, key=lambda x: x[1])
    
    sentiments = {
        0 : 'neutral' ,
        1 : 'positive',
        2 : 'negative',
    }

    if len(tally) == 3:
      if electionMode=='extreme': return df[f'{categoryESG}_fineTuned_maxSentiment'][rowNum]
      if electionMode=='annuled': 
        # print(f'annuled tally: {tally}')
        return 'TIE'
      else:
        # print('THREE-WAY TIE')
        # print(f'modelSentiments: {modelSentiments}')
        
        twitter = ast.literal_eval(df[f'{categoryESG}_twitter_ntl_pos_neg'][rowNum])
        finBERT = ast.literal_eval(df[f'{categoryESG}_finBERT_ntl_pos_neg'][rowNum])

        idxSUM = [i+j for i,j in zip(twitter, finBERT)]

        # print()
        # print('E_finBERT:'.rjust(22), E_finBERT)
        # print('E_twitter:'.rjust(22), E_twitter) 
        # print('E_twitter + E_finBERT:',idxSUM)

        sentIDX = np.argmax(idxSUM)

        return sentiments[sentIDX]
  
    else:
      return tally[0][0]
    

  ### ---- ---- ---- ---- ---- 
  ### RUN CODE
  ### ---- ---- ---- ---- ---- 

  electionModes = ['balanced', 'extreme', 'annuled']
  # electionMode='balanced'

  for df,categoryESG in zip([df_E, df_S, df_G], ['E','S','G']):

    for electionMode in electionModes:

      df[f'vote_{electionMode}'] = ''

      for i in range(len(df)):
        df[f'vote_{electionMode}'][i] = sentimentElection(
                                              df = df, 
                                              rowNum = i, 
                                              categoryESG  = categoryESG, 
                                              electionMode = electionMode
                                          )

      dropTIES = 0
      ### DROP ALL ROWS WHERE THERE IS A TIE
      if dropTIES: df = df[ ~ (df['vote_annuled']=='TIE')]

    # display(df.head(5))


  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 
  import matplotlib.pyplot as plt

  plt.figure(figsize=(5,5))

  end = 50

  plt.plot(df_E['MATCH_SCORE'][0:end], c='green' )
  plt.plot(df_S['MATCH_SCORE'][0:end], c='navy'  )
  plt.plot(df_G['MATCH_SCORE'][0:end], c='orange')
  plt.xlabel('rowNum', fontdict=None, labelpad=None)
  plt.ylabel('Match_Score', fontdict=None, labelpad=None)

  plt.legend(['E','S','G'])

  plt.show()

  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def getMinMax(LIST_DFS):
    MAX = float('-inf')
    MIN = float('inf')

    ESG    = {}
    maxCAT = ''

    for df in LIST_DFS:
      _max = max(df['MATCH_SCORE'])
      _min = min(df['MATCH_SCORE'])

      query = df['QUERY'][0]
      category = 'S' if 'Social' in query else 'G' if 'Governance' in query else 'E'

      if _max > MAX: 
        MAX = _max
        maxCAT = category

      if _min < MIN: 
        MIN = _min
        minCAT = category

      ESG[category] = (_max, _min)

    ESG['Max_Min'] = (MAX, MIN)

    return {
            'E': ESG['E'], 
            'S': ESG['S'], 
            'G': ESG['G'], 
            'MIN': MIN, 
            'MAX': MAX, 
            'minCAT': minCAT, 
            'maxCAT': maxCAT,
          }


  ESG = getMinMax( [df_E, df_S, df_G] )



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def getTopDF(LIST_DFS, TOP_CATEGORY):
    print(f'TOP_CATEGORY: {TOP_CATEGORY}')

    if TOP_CATEGORY == 'E': keyword = 'Environmental' 
    if TOP_CATEGORY == 'S': keyword = 'Social' 
    if TOP_CATEGORY == 'G': keyword = 'Governance' 

    for df in LIST_DFS:
      query = df['QUERY'][0]
      if keyword in query:      
        return df

  topDF = getTopDF( [df_E, df_S, df_G], ESG['maxCAT'] )



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def filterTopN(topDF, LIST_DFS, topN=topN):
    lowerBound = topDF['MATCH_SCORE'][topN]
    print(f'MATCH_SCORE lowerBound : {lowerBound }')

    for idx,df in enumerate(LIST_DFS):
      df = df[df['MATCH_SCORE'] > lowerBound]
      LIST_DFS[idx] = df

    return LIST_DFS


  df_E, df_S, df_G = filterTopN(
      topDF    = topDF, 
      LIST_DFS = [df_E, df_S, df_G], 
      topN     = 20
    )

  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 
  def DF_STATS():
    voteCOLS = [ 'vote_balanced',	'vote_extreme',	'vote_annuled']

    stats = {}

    for df, categoryESG in zip([df_E, df_S, df_G], ['E','S','G'] ) :

      stats[f'DF_{categoryESG}'] = {}


      pos = df[   (df['vote_balanced'] == 'positive') | (df['vote_extreme'] == 'positive') | (df['vote_annuled'] == 'positive') ]
      neg = df[   (df['vote_balanced'] == 'negative') | (df['vote_extreme'] == 'negative') | (df['vote_annuled'] == 'negative') ]
      ntl = df[   (df['vote_balanced'] == 'neutral') | (df['vote_extreme'] == 'neutral') | (df['vote_annuled'] == 'neutral') ]

      posLEN = len(pos)
      negLEN = len(neg)
      ntlLEN = len(ntl)
      dfLEN = len(df)

      stats[f'DF_{categoryESG}']['LEN'] = dfLEN
      stats[f'DF_{categoryESG}']['POS'] = posLEN
      stats[f'DF_{categoryESG}']['NEG'] = negLEN
      stats[f'DF_{categoryESG}']['NTL'] = ntlLEN

      print(f'DF_{categoryESG}: ')
      for k,v in stats[f'DF_{categoryESG}'].items():
        print('\t',k,v)
      display(df)
      df.to_csv("{}{}.csv".format(output_pth, categoryESG))
      print('\n' * 3)

    

  DF_STATS()


  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

if __name__ == '__main__':
  
  E,S,G = main(
        LIST_URLS = [URL_E,URL_S,URL_G],
        topN = 50
      )
# Out:
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_8784\2804416588.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# TOP_CATEGORY: E
# MATCH_SCORE lowerBound : 76.45
# DF_E:
# 	 LEN 20
# 	 POS 4
# 	 NEG 7
# 	 NTL 11
#                                                 QUERY  MATCH_SCORE  PRG_NUM  \
# 0   Emmission. Natural resource consumption. Waste...        84.79      554
# 1   Emmission. Natural resource consumption. Waste...        82.86      163
# 2   Emmission. Natural resource consumption. Waste...        81.82       65
# 3   Emmission. Natural resource consumption. Waste...        81.34      286
# 4   Emmission. Natural resource consumption. Waste...        79.97      553
# 5   Emmission. Natural resource consumption. Waste...        79.97       45
# 6   Emmission. Natural resource consumption. Waste...        79.85       44
# 7   Emmission. Natural resource consumption. Waste...        79.59      228
# 8   Emmission. Natural resource consumption. Waste...        79.23      120
# 9   Emmission. Natural resource consumption. Waste...        78.89      276
# 10  Emmission. Natural resource consumption. Waste...        78.77      229
# 11  Emmission. Natural resource consumption. Waste...        78.41      107
# 12  Emmission. Natural resource consumption. Waste...        78.37      212
# 13  Emmission. Natural resource consumption. Waste...        78.36      231
# 14  Emmission. Natural resource consumption. Waste...        77.26      288
# 15  Emmission. Natural resource consumption. Waste...        77.08      555
# 16  Emmission. Natural resource consumption. Waste...        77.04      236
# 17  Emmission. Natural resource consumption. Waste...        77.04      168
# 18  Emmission. Natural resource consumption. Waste...        76.81      214
# 19  Emmission. Natural resource consumption. Waste...        76.72      260
#
#                                               PRG_TXT  \
# 0   In addition to environmental compliance costs,...
# 1   Climate change resulting from increased concen...
# 2   The Environmental & Applied Solutions segment ...
# 3   The Environmental & Applied Solutions segment ...
# 4   In addition, the Company’s operations, product...
# 5   Industrial. Virtually all of the raw materials...
# 6   Filtration—The filtration, separation and puri...
# 7   Our operations, products and services are subj...
# 8   Our global operations expose us to risks assoc...
# 9   The incremental accretive effect in 2021 of ac...
# 10  In addition, we from time to time incur costs ...
# 11  For a discussion of the environmental laws and...
# 12  In addition to the environmental, health, safe...
# 13  We compete in markets in which we and our cust...
# 14  In 2021, total Environmental & Applied Solutio...
# 15  The Company has recorded a provision for envir...
# 16  Consistent with SEC Regulation SK Item 103, we...
# 17  In addition, some of our businesses purchase c...
# 18  These are not the only regulations that our bu...
# 19  The global spread of a novel strain of coronav...
#
#                                              filtered  \
# 0   ['For example, generators of hazardous substan...
# 1   ['Concern over climate change can also result ...
# 2   ['The Environmental & Applied Solutions segmen...
# 3   ['The Environmental & Applied Solutions segmen...
# 4   ['In addition, the Company’s operations, produ...
# 5   ['Within these segments, demand is driven by e...
# 6   ['Filtration—The filtration, separation and pu...
# 7   ['Our operations, products and services are su...
# 8   ['Our global operations expose us to risks ass...
# 9   ['The incremental accretive effect in 2021 of ...
# 10  ['In addition, we from time to time incur cost...
# 11  ['For a discussion of the environmental laws a...
# 12  ['In addition to the environmental, health, sa...
# 13  ['In these markets, the delay or failure of go...
# 14  ['In 2021, total Environmental & Applied Solut...
# 15  ['The Company has recorded a provision for env...
# 16  ['Consistent with SEC Regulation SK Item 103, ...
# 17  ['The supply chains for our businesses can als...
# 18  ['Failure to comply (or any alleged or perceiv...
# 19  ['The global spread of a novel strain of coron...
#
#                                             FORMATTED E_finBERT_ntl_pos_neg  \
# 0   <b>In addition to environmental compliance cos...   [16.63, 81.1, 2.27]
# 1   <b>Climate change resulting from increased con...  [86.61, 11.92, 1.47]
# 2   <b>The Environmental & Applied Solutions segme...  [0.92, 86.57, 12.51]
# 3   <b>The Environmental & Applied Solutions segme...   [1.26, 92.42, 6.33]
# 4   <b>In addition, the Company’s operations, prod...   [9.37, 88.59, 2.05]
# 5   Industrial. <b>Virtually all of the raw materi...  [0.84, 70.51, 28.65]
# 6   <b>Filtration—The filtration, separation and p...   [1.21, 92.69, 6.09]
# 7   <b>Our operations, products and services are s...   [19.52, 77.8, 2.68]
# 8   <b>Our global operations expose us to risks as...  [86.43, 11.78, 1.79]
# 9   <b>The incremental accretive effect in 2021 of...  [72.77, 25.43, 1.81]
# 10  <b>In addition, we from time to time incur cos...   [14.58, 82.82, 2.6]
# 11  <b>For a discussion of the environmental laws ...    [4.0, 93.83, 2.18]
# 12  <b>In addition to the environmental, health, s...   [21.63, 75.17, 3.2]
# 13  <b>We compete in markets in which we and our c...  [72.57, 25.07, 2.36]
# 14  <b>In 2021, total Environmental & Applied Solu...  [26.73, 4.91, 68.36]
# 15  <b>The Company has recorded a provision for en...   [17.79, 79.8, 2.41]
# 16  <b>Consistent with SEC Regulation SK Item 103,...   [23.46, 71.34, 5.2]
# 17  In addition, some of our businesses purchase c...    [91.5, 7.45, 1.05]
# 18  These are not the only regulations that our bu...  [75.39, 23.18, 1.43]
# 19  <b>The global spread of a novel strain of coro...   [4.24, 86.43, 9.33]
#
#    E_finBERT_maxSentiment E_fineTuned_ntl_pos_neg E_fineTuned_maxSentiment  \
# 0                positive     [99.87, 0.01, 0.12]                  neutral
# 1                 neutral     [0.17, 0.07, 99.75]                 negative
# 2                positive     [99.42, 0.57, 0.01]                  neutral
# 3                positive     [99.99, 0.01, 0.01]                  neutral
# 4                positive      [99.98, 0.0, 0.01]                  neutral
# 5                positive     [0.03, 99.95, 0.02]                 positive
# 6                positive     [99.87, 0.12, 0.01]                  neutral
# 7                positive     [8.85, 0.16, 90.99]                 negative
# 8                 neutral      [0.55, 0.1, 99.35]                 negative
# 9                 neutral      [0.26, 0.1, 99.65]                 negative
# 10               positive     [92.85, 0.05, 7.09]                  neutral
# 11               positive      [99.99, 0.0, 0.01]                  neutral
# 12               positive    [23.17, 0.09, 76.73]                 negative
# 13                neutral     [0.26, 0.31, 99.43]                 negative
# 14               negative     [0.01, 99.97, 0.02]                 positive
# 15               positive      [99.98, 0.0, 0.01]                  neutral
# 16               positive      [99.98, 0.0, 0.02]                  neutral
# 17                neutral     [0.47, 0.05, 99.48]                 negative
# 18                neutral     [1.37, 0.06, 98.58]                 negative
# 19               positive    [15.36, 0.56, 84.08]                 negative
#
#    E_twitter_ntl_pos_neg E_twitter_maxSentiment vote_balanced vote_extreme  \
# 0    [63.75, 2.65, 33.6]                neutral       neutral      neutral
# 1    [29.29, 2.11, 68.6]               negative      negative     negative
# 2   [71.02, 26.16, 2.83]                neutral       neutral      neutral
# 3   [56.98, 41.45, 1.57]                neutral       neutral      neutral
# 4   [51.35, 3.14, 45.51]                neutral       neutral      neutral
# 5   [49.64, 46.33, 4.03]                neutral      positive     positive
# 6   [39.69, 59.65, 0.65]               positive      positive     positive
# 7   [29.86, 2.15, 67.98]               negative      negative     negative
# 8    [30.85, 2.1, 67.05]               negative      negative     negative
# 9   [55.89, 5.06, 39.05]                neutral       neutral      neutral
# 10  [52.49, 3.32, 44.19]                neutral       neutral      neutral
# 11  [67.84, 2.85, 29.31]                neutral       neutral      neutral
# 12   [46.44, 2.5, 51.06]               negative      negative     negative
# 13   [51.0, 4.64, 44.36]                neutral       neutral      neutral
# 14  [67.32, 28.62, 4.07]                neutral       neutral     positive
# 15  [67.25, 4.73, 28.02]                neutral       neutral      neutral
# 16  [77.44, 3.79, 18.78]                neutral       neutral      neutral
# 17   [24.85, 1.25, 73.9]               negative      negative     negative
# 18  [29.59, 1.36, 69.06]               negative      negative     negative
# 19  [80.44, 10.32, 9.24]                neutral      positive     negative
#
#    vote_annuled
# 0       neutral
# 1      negative
# 2       neutral
# 3       neutral
# 4       neutral
# 5      positive
# 6      positive
# 7      negative
# 8      negative
# 9       neutral
# 10      neutral
# 11      neutral
# 12     negative
# 13      neutral
# 14          TIE
# 15      neutral
# 16      neutral
# 17     negative
# 18     negative
# 19          TIE
# DF_S:
# 	 LEN 37
# 	 POS 10
# 	 NEG 9
# 	 NTL 18
#                                                 QUERY  MATCH_SCORE  PRG_NUM  \
# 0   Social. Community. Human rights. Product respo...        80.21      137
# 1   Social. Community. Human rights. Product respo...        79.81      553
# 2   Social. Community. Human rights. Product respo...        79.77      286
# 3   Social. Community. Human rights. Product respo...        79.42       85
# 4   Social. Community. Human rights. Product respo...        79.24       81
# 5   Social. Community. Human rights. Product respo...        79.09      228
# 6   Social. Community. Human rights. Product respo...        79.03      102
# 7   Social. Community. Human rights. Product respo...        78.99       30
# 8   Social. Community. Human rights. Product respo...        78.95       65
# 9   Social. Community. Human rights. Product respo...        78.83      129
# 10  Social. Community. Human rights. Product respo...        78.67      159
# 11  Social. Community. Human rights. Product respo...        78.44      160
# 12  Social. Community. Human rights. Product respo...        78.42       75
# 13  Social. Community. Human rights. Product respo...        78.35       32
# 14  Social. Community. Human rights. Product respo...        78.31      231
# 15  Social. Community. Human rights. Product respo...        78.24      106
# 16  Social. Community. Human rights. Product respo...        78.24       67
# 17  Social. Community. Human rights. Product respo...        78.23       77
# 18  Social. Community. Human rights. Product respo...        78.13      227
# 19  Social. Community. Human rights. Product respo...        78.11      225
# 20  Social. Community. Human rights. Product respo...        77.81       78
# 21  Social. Community. Human rights. Product respo...        77.63      554
# 22  Social. Community. Human rights. Product respo...        77.60       68
# 23  Social. Community. Human rights. Product respo...        77.48      142
# 24  Social. Community. Human rights. Product respo...        77.48      107
# 25  Social. Community. Human rights. Product respo...        77.31       82
# 26  Social. Community. Human rights. Product respo...        77.24      219
# 27  Social. Community. Human rights. Product respo...        77.14      417
# 28  Social. Community. Human rights. Product respo...        77.06      220
# 29  Social. Community. Human rights. Product respo...        77.06      143
# 30  Social. Community. Human rights. Product respo...        76.90       73
# 31  Social. Community. Human rights. Product respo...        76.84        7
# 32  Social. Community. Human rights. Product respo...        76.84      222
# 33  Social. Community. Human rights. Product respo...        76.76       83
# 34  Social. Community. Human rights. Product respo...        76.76       38
# 35  Social. Community. Human rights. Product respo...        76.75       37
# 36  Social. Community. Human rights. Product respo...        76.64      256
#
#                                               PRG_TXT  \
# 0   In 2021 approximately 62% of our sales were de...
# 1   In addition, the Company’s operations, product...
# 2   The Environmental & Applied Solutions segment ...
# 3   The Company faces extensive government regulat...
# 4   Safety and Risk Management. Associate safety i...
# 5   Our operations, products and services are subj...
# 6   Federal consumer protection and unfair competi...
# 7   With respect to the regulated medical devices ...
# 8   The Environmental & Applied Solutions segment ...
# 9   Our businesses operate in industries that are ...
# 10  Any inability to maintain reliable information...
# 11  Manufacturing or design defects or bugs in, un...
# 12  Danaher is committed to attracting, developing...
# 13  Our operations, products and services also exp...
# 14  We compete in markets in which we and our cust...
# 15  Data Privacy and Security Laws As a global org...
# 16  Product Identification—The Company’s product i...
# 17  We have leveraged DBS with the goal of driving...
# 18  Our operations, products and services expose u...
# 19  Certain modifications to our products may requ...
# 20  Compensation and Benefits. We are committed to...
# 21  In addition to environmental compliance costs,...
# 22  Typical users of these products include manufa...
# 23  Certain of our businesses rely on relationship...
# 24  For a discussion of the environmental laws and...
# 25  The health and wellbeing of our associates has...
# 26  To varying degrees, these regulators require u...
# 27  Revenue Recognition—The Company derives revenu...
# 28  Government authorities may conclude that our b...
# 29  For certain of our businesses, success in pene...
# 30  Although the Company’s businesses generally op...
# 31  Business Risk Factors Unresolved Staff Comment...
# 32  As a part of the regulatory process of obtaini...
# 33  The Company conducts R&D activities for the pu...
# 34  Underpinned by these five Core Values as well ...
# 35  DBS is not only the set of business processes ...
# 36  As a result of the Company’s geographic and in...
#
#                                              filtered  \
# 0   ['Our nonU.S. business (and particularly our b...
# 1   ['In addition, the Company’s operations, produ...
# 2   ['The Company’s product identification busines...
# 3   ['The Company faces extensive government regul...
# 4   ['Our Environment, Health and Safety (EHS) Pol...
# 5   ['Our operations, products and services are su...
# 6   ['Federal consumer protection and unfair compe...
# 7   ['With respect to the regulated medical device...
# 8   ['The Company’s Environmental & Applied Soluti...
# 9   ['In addition, significant shifts in industry ...
# 10  ['In addition, compliance with the varying dat...
# 11  ['Recalls, removals and product liability and ...
# 12  ['At its core, DBS reflects a commitment to us...
# 13  ['Our operations, products and services also e...
# 14  ['We compete in markets in which we and our cu...
# 15  ['For example, in the United States, HIPAA pri...
# 16  ['The business’ expertise in inspiring, virtua...
# 17  ['We have leveraged DBS with the goal of drivi...
# 18  ['Our operations, products and services expose...
# 19  ['Certain modifications to our products may re...
# 20  ['We are committed to offering competitive com...
# 21  ['The Company has received notification from t...
# 22  ['Customers in these industries choose supplie...
# 23  ['Certain of our businesses rely on relationsh...
# 24  ['For a discussion of the environmental laws a...
# 25  ['We launched a global Employee Assistance Pro...
# 26  ['We are also subject to various laws regulati...
# 27  ['To indicate the transfer of control, the Com...
# 28  ['Failure to obtain required regulatory cleara...
# 29  ['In addition, if we or any of our collaborati...
# 30  ['Key competitive factors vary among the Compa...
# 31  ['Business Risk Factors Unresolved Staff Comme...
# 32  ['As a part of the regulatory process of obtai...
# 33  ['For a discussion of the risks related to the...
# 34  ['Underpinned by these five Core Values as wel...
# 35  ['As reflected in our logo, DBS features five ...
# 36  ['As a result of the Company’s geographic and ...
#
#                                             FORMATTED S_finBERT_ntl_pos_neg  \
# 0   In 2021 approximately 62% of our sales were de...  [12.34, 78.32, 9.34]
# 1   <b>In addition, the Company’s operations, prod...   [9.37, 88.59, 2.05]
# 2   <b>The Environmental & Applied Solutions segme...   [1.26, 92.42, 6.33]
# 3   <b>The Company faces extensive government regu...   [3.47, 94.28, 2.25]
# 4   Safety and Risk Management. <b>Associate safet...   [11.4, 85.43, 3.17]
# 5   <b>Our operations, products and services are s...   [19.52, 77.8, 2.68]
# 6   <b>Federal consumer protection and unfair comp...  [10.47, 87.32, 2.21]
# 7   <b>With respect to the regulated medical devic...  [81.04, 17.59, 1.37]
# 8   <b>The Environmental & Applied Solutions segme...  [0.92, 86.57, 12.51]
# 9   Our businesses operate in industries that are ...   [76.9, 16.46, 6.64]
# 10  <b>Any inability to maintain reliable informat...  [86.49, 12.08, 1.43]
# 11  <b>Manufacturing or design defects or bugs in,...   [88.05, 10.85, 1.1]
# 12  Danaher is committed to attracting, developing...  [0.99, 81.98, 17.03]
# 13  <b>Our operations, products and services also ...  [58.35, 39.34, 2.31]
# 14  <b>We compete in markets in which we and our c...  [72.57, 25.07, 2.36]
# 15  <b>Data Privacy and Security Laws As a global ...   [6.62, 90.06, 3.32]
# 16  <b>Product Identification—The Company’s produc...  [1.03, 84.09, 14.88]
# 17  <b>We have leveraged DBS with the goal of driv...  [1.04, 70.83, 28.12]
# 18  <b>Our operations, products and services expos...   [55.87, 41.83, 2.3]
# 19  <b>Certain modifications to our products may r...   [32.81, 64.79, 2.4]
# 20  Compensation and Benefits. <b>We are committed...  [1.22, 88.71, 10.07]
# 21  <b>In addition to environmental compliance cos...   [16.63, 81.1, 2.27]
# 22  <b>Typical users of these products include man...   [1.64, 95.14, 3.22]
# 23  <b>Certain of our businesses rely on relations...   [91.46, 6.93, 1.61]
# 24  <b>For a discussion of the environmental laws ...    [4.0, 93.83, 2.18]
# 25  The health and wellbeing of our associates has...  [1.28, 38.05, 60.67]
# 26  <b>To varying degrees, these regulators requir...  [19.01, 78.36, 2.64]
# 27  <b>Revenue Recognition—The Company derives rev...   [14.73, 82.1, 3.17]
# 28  Government authorities may conclude that our b...   [90.73, 8.06, 1.21]
# 29  <b>For certain of our businesses, success in p...  [83.25, 15.23, 1.51]
# 30  <b>Although the Company’s businesses generally...    [2.75, 90.54, 6.7]
# 31  <b>Business Risk Factors Unresolved Staff Comm...   [5.71, 92.48, 1.81]
# 32  <b>As a part of the regulatory process of obta...   [71.45, 26.4, 2.16]
# 33  <b>The Company conducts R&D activities for the...  [0.82, 60.62, 38.56]
# 34  <b>Underpinned by these five Core Values as we...  [0.93, 83.83, 15.24]
# 35  DBS is not only the set of business processes ...    [1.6, 93.63, 4.77]
# 36  <b>As a result of the Company’s geographic and...   [0.93, 18.27, 80.8]
#
#    S_finBERT_maxSentiment S_fineTuned_ntl_pos_neg S_fineTuned_maxSentiment  \
# 0                positive      [0.6, 99.33, 0.07]                 positive
# 1                positive      [99.98, 0.0, 0.01]                  neutral
# 2                positive     [99.99, 0.01, 0.01]                  neutral
# 3                positive      [99.99, 0.0, 0.01]                  neutral
# 4                positive      [99.99, 0.0, 0.01]                  neutral
# 5                positive     [8.85, 0.16, 90.99]                 negative
# 6                positive      [99.99, 0.0, 0.01]                  neutral
# 7                 neutral     [2.71, 0.05, 97.24]                 negative
# 8                positive     [99.42, 0.57, 0.01]                  neutral
# 9                 neutral     [2.14, 92.37, 5.49]                 positive
# 10                neutral     [0.85, 0.09, 99.07]                 negative
# 11                neutral     [0.26, 0.05, 99.68]                 negative
# 12               positive     [99.81, 0.19, 0.01]                  neutral
# 13                neutral      [4.53, 0.07, 95.4]                 negative
# 14                neutral     [0.26, 0.31, 99.43]                 negative
# 15               positive     [99.97, 0.02, 0.01]                  neutral
# 16               positive     [0.33, 99.65, 0.02]                 positive
# 17               positive     [0.03, 99.95, 0.02]                 positive
# 18                neutral     [6.05, 0.07, 93.88]                 negative
# 19               positive     [99.98, 0.01, 0.01]                  neutral
# 20               positive    [73.98, 25.97, 0.06]                  neutral
# 21               positive     [99.87, 0.01, 0.12]                  neutral
# 22               positive     [99.99, 0.01, 0.01]                  neutral
# 23                neutral     [0.91, 0.04, 99.05]                 negative
# 24               positive      [99.99, 0.0, 0.01]                  neutral
# 25               negative     [0.11, 99.88, 0.02]                 positive
# 26               positive     [99.82, 0.01, 0.17]                  neutral
# 27               positive     [99.99, 0.01, 0.01]                  neutral
# 28                neutral     [0.41, 0.04, 99.55]                 negative
# 29                neutral     [0.68, 0.04, 99.27]                 negative
# 30               positive     [99.38, 0.58, 0.04]                  neutral
# 31               positive      [99.99, 0.0, 0.01]                  neutral
# 32                neutral      [1.64, 0.06, 98.3]                 negative
# 33               positive     [0.03, 99.95, 0.02]                 positive
# 34               positive     [99.99, 0.01, 0.01]                  neutral
# 35               positive     [99.99, 0.01, 0.01]                  neutral
# 36               negative     [0.03, 99.95, 0.02]                 positive
#
#     S_twitter_ntl_pos_neg S_twitter_maxSentiment vote_balanced vote_extreme  \
# 0   [66.39, 11.94, 21.67]                neutral      positive     positive
# 1    [51.35, 3.14, 45.51]                neutral       neutral      neutral
# 2    [56.98, 41.45, 1.57]                neutral       neutral      neutral
# 3    [61.87, 4.44, 33.69]                neutral       neutral      neutral
# 4    [66.91, 5.98, 27.11]                neutral       neutral      neutral
# 5    [29.86, 2.15, 67.98]               negative      negative     negative
# 6     [51.23, 2.3, 46.47]                neutral       neutral      neutral
# 7    [23.23, 1.02, 75.74]               negative      negative     negative
# 8    [71.02, 26.16, 2.83]                neutral       neutral      neutral
# 9   [63.83, 13.12, 23.05]                neutral       neutral      neutral
# 10   [37.13, 2.13, 60.74]               negative      negative     negative
# 11    [18.7, 0.69, 80.61]               negative      negative     negative
# 12   [30.67, 68.88, 0.46]               positive      positive     positive
# 13    [10.56, 0.34, 89.1]               negative      negative     negative
# 14    [51.0, 4.64, 44.36]                neutral       neutral      neutral
# 15    [72.1, 5.76, 22.14]                neutral       neutral      neutral
# 16   [53.43, 45.18, 1.39]                neutral      positive     positive
# 17   [46.48, 53.09, 0.42]               positive      positive     positive
# 18   [10.63, 0.36, 89.01]               negative      negative     negative
# 19   [70.74, 2.08, 27.18]                neutral       neutral      neutral
# 20   [30.67, 68.68, 0.66]               positive      positive     positive
# 21    [63.75, 2.65, 33.6]                neutral       neutral      neutral
# 22    [73.98, 24.0, 2.02]                neutral       neutral      neutral
# 23    [43.53, 3.1, 53.37]               negative      negative     negative
# 24   [67.84, 2.85, 29.31]                neutral       neutral      neutral
# 25   [37.69, 61.35, 0.96]               positive      positive     positive
# 26   [54.84, 3.57, 41.59]                neutral       neutral      neutral
# 27   [78.48, 6.84, 14.68]                neutral       neutral      neutral
# 28   [25.51, 1.35, 73.14]               negative      negative     negative
# 29   [25.48, 1.54, 72.98]               negative      negative     negative
# 30   [56.93, 6.21, 36.85]                neutral       neutral      neutral
# 31   [78.16, 3.13, 18.71]                neutral       neutral      neutral
# 32   [49.99, 2.81, 47.19]                neutral       neutral      neutral
# 33   [40.84, 58.41, 0.74]               positive      positive     positive
# 34   [41.62, 57.99, 0.39]               positive      positive     positive
# 35   [19.62, 80.07, 0.32]               positive      positive     positive
# 36    [41.88, 56.9, 1.22]               positive      positive     positive
#
#    vote_annuled
# 0      positive
# 1       neutral
# 2       neutral
# 3       neutral
# 4       neutral
# 5      negative
# 6       neutral
# 7      negative
# 8       neutral
# 9       neutral
# 10     negative
# 11     negative
# 12     positive
# 13     negative
# 14      neutral
# 15      neutral
# 16     positive
# 17     positive
# 18     negative
# 19      neutral
# 20     positive
# 21      neutral
# 22      neutral
# 23     negative
# 24      neutral
# 25     positive
# 26      neutral
# 27      neutral
# 28     negative
# 29     negative
# 30      neutral
# 31      neutral
# 32      neutral
# 33     positive
# 34     positive
# 35     positive
# 36     positive
# DF_G:
# 	 LEN 21
# 	 POS 4
# 	 NEG 2
# 	 NTL 16
#                                                 QUERY  MATCH_SCORE  PRG_NUM  \
# 0   Governance. CSR strategy. Management. Sharehol...        81.01        7
# 1   Governance. CSR strategy. Management. Sharehol...        79.89      592
# 2   Governance. CSR strategy. Management. Sharehol...        79.64       75
# 3   Governance. CSR strategy. Management. Sharehol...        79.13      379
# 4   Governance. CSR strategy. Management. Sharehol...        79.11      375
# 5   Governance. CSR strategy. Management. Sharehol...        78.73      374
# 6   Governance. CSR strategy. Management. Sharehol...        78.65      384
# 7   Governance. CSR strategy. Management. Sharehol...        78.54      378
# 8   Governance. CSR strategy. Management. Sharehol...        78.46      405
# 9   Governance. CSR strategy. Management. Sharehol...        78.36      385
# 10  Governance. CSR strategy. Management. Sharehol...        78.23      381
# 11  Governance. CSR strategy. Management. Sharehol...        78.18      584
# 12  Governance. CSR strategy. Management. Sharehol...        78.17      589
# 13  Governance. CSR strategy. Management. Sharehol...        77.82      355
# 14  Governance. CSR strategy. Management. Sharehol...        77.61      594
# 15  Governance. CSR strategy. Management. Sharehol...        77.53      303
# 16  Governance. CSR strategy. Management. Sharehol...        77.11      159
# 17  Governance. CSR strategy. Management. Sharehol...        76.99      583
# 18  Governance. CSR strategy. Management. Sharehol...        76.96      386
# 19  Governance. CSR strategy. Management. Sharehol...        76.58      326
# 20  Governance. CSR strategy. Management. Sharehol...        76.57      593
#
#                                               PRG_TXT  \
# 0   Business Risk Factors Unresolved Staff Comment...
# 1   The information required by this Item is incor...
# 2   Danaher is committed to attracting, developing...
# 3   As indicated in the accompanying Report of Man...
# 4   The Company’s management assessed the effectiv...
# 5   The management of the Company is responsible f...
# 6   A company’s internal control over financial re...
# 7   We have audited Danaher Corporation and subsid...
# 8   Accounting Principles—The accompanying financi...
# 9   Because of its inherent limitations, internal ...
# 10  The Company’s management is responsible for ma...
# 11  Management’s annual report on its internal con...
# 12  Other than the information below, the informat...
# 13  Management’s discussion and analysis of the Co...
# 14  The information required by this Item is incor...
# 15  The amount of income taxes the Company pays is...
# 16  Any inability to maintain reliable information...
# 17  The Company’s management, with the participati...
# 18  We also have audited, in accordance with the s...
# 19  Management assesses the Company’s liquidity in...
# 20  The information required by this Item is incor...
#
#                                              filtered  \
# 0   ['Business Risk Factors Unresolved Staff Comme...
# 1   ['The information required by this Item is inc...
# 2   ['Danaher’s Board of Directors reviews the Com...
# 3   ['As indicated in the accompanying Report of M...
# 4   ['Based on this assessment, management conclud...
# 5   ['The management of the Company is responsible...
# 6   ['A company’s internal control over financial ...
# 7   ['We have audited Danaher Corporation and subs...
# 8   ['The Consolidated Financial Statements includ...
# 9   ['Ernst & Young LLP Tysons, Virginia February ...
# 10  ['The Company’s management is responsible for ...
# 11  ['Management’s annual report on its internal c...
# 12  ['Other than the information below, the inform...
# 13  ['Management’s discussion and analysis of the ...
# 14  ['The information required by this Item is inc...
# 15  ['Management performs a comprehensive review o...
# 16                                                 []
# 17  ['The Company’s management, with the participa...
# 18  ['We also have audited, in accordance with the...
# 19  ['Management assesses the Company’s liquidity ...
# 20  ['The information required by this Item is inc...
#
#                                             FORMATTED G_finBERT_ntl_pos_neg  \
# 0   <b>Business Risk Factors Unresolved Staff Comm...   [5.71, 92.48, 1.81]
# 1   <b>The information required by this Item is in...   [4.77, 93.34, 1.89]
# 2   Danaher is committed to attracting, developing...  [0.99, 81.98, 17.03]
# 3   <b>As indicated in the accompanying Report of ...   [5.72, 92.09, 2.19]
# 4   <b>The Company’s management assessed the effec...  [1.31, 82.28, 16.41]
# 5   <b>The management of the Company is responsibl...    [2.4, 94.89, 2.71]
# 6   <b>A company’s internal control over financial...   [3.86, 93.35, 2.79]
# 7   <b>We have audited Danaher Corporation and sub...   [1.12, 85.78, 13.1]
# 8   <b>Accounting Principles—The accompanying fina...   [17.8, 80.04, 2.16]
# 9   Because of its inherent limitations, internal ...   [5.18, 90.98, 3.84]
# 10  <b>The Company’s management is responsible for...   [2.28, 94.88, 2.85]
# 11  <b>Management’s annual report on its internal ...   [2.49, 94.96, 2.55]
# 12  <b>Other than the information below, the infor...   [2.69, 95.23, 2.08]
# 13  <b>Management’s discussion and analysis of the...  [16.41, 80.79, 2.81]
# 14  <b>The information required by this Item is in...   [2.79, 95.17, 2.04]
# 15  The amount of income taxes the Company pays is...    [2.55, 94.6, 2.86]
# 16  Any inability to maintain reliable information...  [86.49, 12.08, 1.43]
# 17  <b>The Company’s management, with the particip...  [2.08, 79.96, 17.97]
# 18  <b>We also have audited, in accordance with th...    [1.24, 91.1, 7.66]
# 19  <b>Management assesses the Company’s liquidity...  [0.88, 19.53, 79.59]
# 20  <b>The information required by this Item is in...   [4.47, 93.45, 2.08]
#
#    G_finBERT_maxSentiment G_fineTuned_ntl_pos_neg G_fineTuned_maxSentiment  \
# 0                positive      [99.99, 0.0, 0.01]                  neutral
# 1                positive      [99.99, 0.0, 0.01]                  neutral
# 2                positive     [99.81, 0.19, 0.01]                  neutral
# 3                positive      [99.98, 0.0, 0.01]                  neutral
# 4                positive     [99.93, 0.06, 0.01]                  neutral
# 5                positive      [99.99, 0.0, 0.01]                  neutral
# 6                positive     [99.99, 0.01, 0.01]                  neutral
# 7                positive     [99.99, 0.01, 0.01]                  neutral
# 8                positive      [99.99, 0.0, 0.01]                  neutral
# 9                positive    [37.27, 0.07, 62.66]                 negative
# 10               positive      [99.99, 0.0, 0.01]                  neutral
# 11               positive      [99.99, 0.0, 0.01]                  neutral
# 12               positive      [99.99, 0.0, 0.01]                  neutral
# 13               positive     [99.99, 0.01, 0.01]                  neutral
# 14               positive      [99.99, 0.0, 0.01]                  neutral
# 15               positive      [99.99, 0.0, 0.01]                  neutral
# 16                neutral     [0.85, 0.09, 99.07]                 negative
# 17               positive     [2.27, 97.67, 0.06]                 positive
# 18               positive      [99.99, 0.0, 0.01]                  neutral
# 19               negative     [0.75, 99.21, 0.04]                 positive
# 20               positive      [99.99, 0.0, 0.01]                  neutral
#
#    G_twitter_ntl_pos_neg G_twitter_maxSentiment vote_balanced vote_extreme  \
# 0   [78.16, 3.13, 18.71]                neutral       neutral      neutral
# 1    [80.22, 3.88, 15.9]                neutral       neutral      neutral
# 2   [30.67, 68.88, 0.46]               positive      positive     positive
# 3   [54.42, 3.46, 42.12]                neutral       neutral      neutral
# 4   [58.31, 41.14, 0.55]                neutral       neutral      neutral
# 5    [88.14, 3.35, 8.51]                neutral       neutral      neutral
# 6   [86.26, 11.18, 2.56]                neutral       neutral      neutral
# 7   [70.27, 28.52, 1.21]                neutral       neutral      neutral
# 8   [69.04, 9.55, 21.41]                neutral       neutral      neutral
# 9    [76.11, 6.0, 17.88]                neutral      positive     negative
# 10   [88.64, 6.08, 5.28]                neutral       neutral      neutral
# 11    [94.24, 3.6, 2.16]                neutral       neutral      neutral
# 12   [89.79, 3.13, 7.08]                neutral       neutral      neutral
# 13   [88.07, 5.04, 6.89]                neutral       neutral      neutral
# 14   [93.71, 4.02, 2.27]                neutral       neutral      neutral
# 15  [84.97, 3.61, 11.42]                neutral       neutral      neutral
# 16  [37.13, 2.13, 60.74]               negative      negative     negative
# 17   [84.17, 14.7, 1.12]                neutral      positive     positive
# 18  [76.08, 4.53, 19.39]                neutral       neutral      neutral
# 19  [37.63, 61.97, 0.41]               positive      positive     positive
# 20   [93.59, 3.74, 2.67]                neutral       neutral      neutral
#
#    vote_annuled
# 0       neutral
# 1       neutral
# 2      positive
# 3       neutral
# 4       neutral
# 5       neutral
# 6       neutral
# 7       neutral
# 8       neutral
# 9           TIE
# 10      neutral
# 11      neutral
# 12      neutral
# 13      neutral
# 14      neutral
# 15      neutral
# 16     negative
# 17     positive
# 18      neutral
# 19     positive
# 20      neutral
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [23], line 263
#     259   ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
#     261 if __name__ == '__main__':
# --> 263   E,S,G = main(
#     264         LIST_URLS = [URL_E,URL_S,URL_G],
#     265         topN = 50
#     266       )
#
# TypeError: cannot unpack non-iterable NoneType object
