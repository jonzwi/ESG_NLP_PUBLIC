# %%
import pandas as pd
pd.set_option('max_colwidth', 50)

import numpy as np
import ast

import os

### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

# if not 'cleanURL.py' in os.listdir():
#   cleanURL_PY = '1WFCzNdHClqA2f8n8-82Vbq_0tjInh65w'

#   !gdown $cleanURL_PY

#   from cleanURL import cleanURL


### AMZN data
# URL_E = 'https://drive.google.com/file/d/13dFrfYJp-QskHvojt-rYryXi1E5uiiDO/view?usp=sharing'
# URL_S = 'https://drive.google.com/file/d/1Hb-nZkOmoJN9LlZhO1d4cfkilof-F8vH/view?usp=sharing'
# URL_G = 'https://drive.google.com/file/d/18C9mZH8EQv3lsbCNc8Nj2-1od7R8XkgE/view?usp=sharing'

company = "BE"

URL_E = "public/Formatted_Data/formatted_{}_10K_E.csv".format(company)
URL_S = "public/Formatted_Data/formatted_{}_10K_S.csv".format(company)
URL_G = "public/Formatted_Data/formatted_{}_10K_G.csv".format(company)

output_pth = "public/Formatted_Filtered/formatted_{}_10K_".format(company)


os.chdir("C:/Users/jleckron/ReactProjects/esgnlpfrontend")


### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

def main(LIST_URLS, topN=50):

  E,S,G = LIST_URLS

  df_E = pd.read_csv(E)
  df_S = pd.read_csv(S)
  df_G = pd.read_csv(G)   

#   df_E = cleanURL(E)
#   df_S = cleanURL(S)
#   df_G = cleanURL(G)



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 


  def sentimentElection(df, rowNum, categoryESG, electionMode='balanced'):

    if categoryESG not in ['E','S','G']:
      print(f'categoryESG must be "E", "S", or "G"' )
      return


    maxSentimentCols = [ col for col in df.columns if 'maxSentiment' in col ]
    modelSentiments  = []

    for col in maxSentimentCols:
      modelSentiments.append( df[col][rowNum] )
    
    tally = sorted({ k:modelSentiments.count(k) for k in set(modelSentiments) }.items(), reverse=True, key=lambda x: x[1])
    
    sentiments = {
        0 : 'neutral' ,
        1 : 'positive',
        2 : 'negative',
    }

    if len(tally) == 3:
      if electionMode=='extreme': return df[f'{categoryESG}_fineTuned_maxSentiment'][rowNum]
      if electionMode=='annuled': 
        # print(f'annuled tally: {tally}')
        return 'TIE'
      else:
        # print('THREE-WAY TIE')
        # print(f'modelSentiments: {modelSentiments}')
        
        twitter = ast.literal_eval(df[f'{categoryESG}_twitter_ntl_pos_neg'][rowNum])
        finBERT = ast.literal_eval(df[f'{categoryESG}_finBERT_ntl_pos_neg'][rowNum])

        idxSUM = [i+j for i,j in zip(twitter, finBERT)]

        # print()
        # print('E_finBERT:'.rjust(22), E_finBERT)
        # print('E_twitter:'.rjust(22), E_twitter) 
        # print('E_twitter + E_finBERT:',idxSUM)

        sentIDX = np.argmax(idxSUM)

        return sentiments[sentIDX]
  
    else:
      return tally[0][0]
    

  ### ---- ---- ---- ---- ---- 
  ### RUN CODE
  ### ---- ---- ---- ---- ---- 

  electionModes = ['balanced', 'extreme', 'annuled']
  # electionMode='balanced'

  for df,categoryESG in zip([df_E, df_S, df_G], ['E','S','G']):

    for electionMode in electionModes:

      df[f'vote_{electionMode}'] = ''

      for i in range(len(df)):
        df[f'vote_{electionMode}'][i] = sentimentElection(
                                              df = df, 
                                              rowNum = i, 
                                              categoryESG  = categoryESG, 
                                              electionMode = electionMode
                                          )

      dropTIES = 0
      ### DROP ALL ROWS WHERE THERE IS A TIE
      if dropTIES: df = df[ ~ (df['vote_annuled']=='TIE')]

    # display(df.head(5))


  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 
  import matplotlib.pyplot as plt

  plt.figure(figsize=(5,5))

  end = 50

  plt.plot(df_E['MATCH_SCORE'][0:end], c='green' )
  plt.plot(df_S['MATCH_SCORE'][0:end], c='navy'  )
  plt.plot(df_G['MATCH_SCORE'][0:end], c='orange')

  plt.legend(['E','S','G'])

  plt.show()

  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def getMinMax(LIST_DFS):
    MAX = float('-inf')
    MIN = float('inf')

    ESG    = {}
    maxCAT = ''

    for df in LIST_DFS:
      _max = max(df['MATCH_SCORE'])
      _min = min(df['MATCH_SCORE'])

      query = df['QUERY'][0]
      category = 'S' if 'Social' in query else 'G' if 'Governance' in query else 'E'

      if _max > MAX: 
        MAX = _max
        maxCAT = category

      if _min < MIN: 
        MIN = _min
        minCAT = category

      ESG[category] = (_max, _min)

    ESG['Max_Min'] = (MAX, MIN)

    return {
            'E': ESG['E'], 
            'S': ESG['S'], 
            'G': ESG['G'], 
            'MIN': MIN, 
            'MAX': MAX, 
            'minCAT': minCAT, 
            'maxCAT': maxCAT,
          }


  ESG = getMinMax( [df_E, df_S, df_G] )



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def getTopDF(LIST_DFS, TOP_CATEGORY):
    print(f'TOP_CATEGORY: {TOP_CATEGORY}')

    if TOP_CATEGORY == 'E': keyword = 'Environmental' 
    if TOP_CATEGORY == 'S': keyword = 'Social' 
    if TOP_CATEGORY == 'G': keyword = 'Governance' 

    for df in LIST_DFS:
      query = df['QUERY'][0]
      if keyword in query:      
        return df

  topDF = getTopDF( [df_E, df_S, df_G], ESG['maxCAT'] )



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

  def filterTopN(topDF, LIST_DFS, topN=topN):
    lowerBound = topDF['MATCH_SCORE'][topN]
    print(f'MATCH_SCORE lowerBound : {lowerBound }')

    for idx,df in enumerate(LIST_DFS):
      df = df[df['MATCH_SCORE'] > lowerBound]
      LIST_DFS[idx] = df

    return LIST_DFS


  df_E, df_S, df_G = filterTopN(
      topDF    = topDF, 
      LIST_DFS = [df_E, df_S, df_G], 
      topN     = 20
    )

  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 
  def DF_STATS():
    voteCOLS = [ 'vote_balanced',	'vote_extreme',	'vote_annuled']

    stats = {}

    for df, categoryESG in zip([df_E, df_S, df_G], ['E','S','G'] ) :

      stats[f'DF_{categoryESG}'] = {}


      pos = df[   (df['vote_balanced'] == 'positive') | (df['vote_extreme'] == 'positive') | (df['vote_annuled'] == 'positive') ]
      neg = df[   (df['vote_balanced'] == 'negative') | (df['vote_extreme'] == 'negative') | (df['vote_annuled'] == 'negative') ]
      ntl = df[   (df['vote_balanced'] == 'neutral') | (df['vote_extreme'] == 'neutral') | (df['vote_annuled'] == 'neutral') ]

      posLEN = len(pos)
      negLEN = len(neg)
      ntlLEN = len(ntl)
      dfLEN = len(df)

      stats[f'DF_{categoryESG}']['LEN'] = dfLEN
      stats[f'DF_{categoryESG}']['POS'] = posLEN
      stats[f'DF_{categoryESG}']['NEG'] = negLEN
      stats[f'DF_{categoryESG}']['NTL'] = ntlLEN

      print(f'DF_{categoryESG}: ')
      for k,v in stats[f'DF_{categoryESG}'].items():
        print('\t',k,v)
      display(df)
      print('\n' * 3)
      filePath = "{}{}.csv".format(output_pth, categoryESG)
      df.to_csv(filePath)
    




    

  DF_STATS()

  return df_E, df_S, df_G



  ### ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- ---- 

if __name__ == '__main__':
  
  E,S,G = main(
        LIST_URLS = [URL_E,URL_S,URL_G],
        topN = 50
      )
# Out:
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# C:\Users\jleckron\AppData\Local\Temp\ipykernel_13116\652745798.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'vote_{electionMode}'][i] = sentimentElection(
# TOP_CATEGORY: E
# MATCH_SCORE lowerBound : 80.05
# DF_E:
# 	 LEN 20
# 	 POS 8
# 	 NEG 5
# 	 NTL 7
#                                                 QUERY  MATCH_SCORE  PRG_NUM  \
# 0   Emission. Natural resource consumption. Waste....        88.28      212
# 1   Emission. Natural resource consumption. Waste....        87.34       72
# 2   Emission. Natural resource consumption. Waste....        86.28       27
# 3   Emission. Natural resource consumption. Waste....        84.64       19
# 4   Emission. Natural resource consumption. Waste....        84.42      207
# 5   Emission. Natural resource consumption. Waste....        83.16       17
# 6   Emission. Natural resource consumption. Waste....        82.58      209
# 7   Emission. Natural resource consumption. Waste....        82.56       71
# 8   Emission. Natural resource consumption. Waste....        81.94       10
# 9   Emission. Natural resource consumption. Waste....        81.67       66
# 10  Emission. Natural resource consumption. Waste....        81.06      214
# 11  Emission. Natural resource consumption. Waste....        81.03      204
# 12  Emission. Natural resource consumption. Waste....        80.96       24
# 13  Emission. Natural resource consumption. Waste....        80.80      262
# 14  Emission. Natural resource consumption. Waste....        80.78      210
# 15  Emission. Natural resource consumption. Waste....        80.75      208
# 16  Emission. Natural resource consumption. Waste....        80.65       28
# 17  Emission. Natural resource consumption. Waste....        80.25      135
# 18  Emission. Natural resource consumption. Waste....        80.18       65
# 19  Emission. Natural resource consumption. Waste....        80.18       82
#
#                                               PRG_TXT  \
# 0   The current generation of our Energy Servers t...
# 1   The direct impacts of climate change on energy...
# 2   Sustainability. Our Energy Servers uniquely ad...
# 3   Increasing focus on reducing harmful local emi...
# 4   We are committed to compliance with applicable...
# 5   Stakeholders across industries grapple with th...
# 6   For example, natural gas, which is the primary...
# 7   Global warming and resulting extreme weather a...
# 8   Our technology, invented in the United States,...
# 9   We are driven by the promise of our contributi...
# 10  The market for electricity generation products...
# 11  The construction, installation, and operation ...
# 12  Marine Transportation. We have also adapted ou...
# 13  We utilize a sourcing strategy that emphasizes...
# 14  Some states in which we operate, including New...
# 15  Maintaining environmental compliance can be ch...
# 16  We are focused on product innovation, includin...
# 17  We believe that a customer’s decision to purch...
# 18  As a manufacturer, our commitment to sustainab...
# 19  Several states in which we currently operate, ...
#
#                                              filtered  \
# 0   ['The current generation of our Energy Servers...
# 1   ['New or more stringent international accords,...
# 2   ['Our projects lower carbon emissions by displ...
# 3   ['Policymakers are rightly increasing the emph...
# 4   ['Many of our customers who purchase our Energ...
# 5   ['These acute issues further add to a chronic ...
# 6   ['For example, natural gas, which is the prima...
# 7   ['We closely follow the impacts of climate cha...
# 8   ['Our fuelflexible Bloom Energy Servers can us...
# 9   ['We are working to make our technology availa...
# 10  ['These regulations, tariffs and policies are ...
# 11  ['The construction, installation, and operatio...
# 12  ['The marine sector is a significant source of...
# 13  ['Physical, regulatory, technological, market,...
# 14  ['Other states in which we currently operate, ...
# 15  ['Most existing environmental laws and regulat...
# 16  ['We are also focused on scaling use of renewa...
# 17  ['Factors that could influence these prices an...
# 18  ['As a manufacturer, our commitment to sustain...
# 19  ['Several states in which we currently operate...
#
#                                             FORMATTED E_finBERT_ntl_pos_neg  \
# 0   <b>The current generation of our Energy Server...  [77.99, 20.09, 1.91]
# 1   <b>The direct impacts of climate change on ene...  [11.6, 71.79, 16.61]
# 2   Sustainability. <b>Our Energy Servers uniquely...  [1.18, 36.58, 62.23]
# 3   <b>Increasing focus on reducing harmful local ...  [7.31, 44.81, 47.89]
# 4   <b>We are committed to compliance with applica...  [30.21, 67.06, 2.73]
# 5   <b>Stakeholders across industries grapple with...  [65.57, 30.15, 4.28]
# 6   <b>For example, natural gas, which is the prim...  [28.16, 67.13, 4.71]
# 7   <b>Global warming and resulting extreme weathe...   [1.49, 90.99, 7.52]
# 8   Our technology, invented in the United States,...   [0.8, 44.19, 55.02]
# 9   <b>We are driven by the promise of our contrib...  [0.69, 23.34, 75.98]
# 10  <b>The market for electricity generation produ...  [72.68, 22.06, 5.26]
# 11  <b>The construction, installation, and operati...   [43.78, 54.2, 2.01]
# 12  Marine Transportation. We have also adapted ou...   [0.87, 39.14, 60.0]
# 13  We utilize a sourcing strategy that emphasizes...  [87.73, 10.95, 1.31]
# 14  <b>Some states in which we operate, including ...  [42.64, 54.22, 3.14]
# 15  <b>Maintaining environmental compliance can be...   [30.76, 65.9, 3.34]
# 16  <b>We are focused on product innovation, inclu...  [0.85, 54.57, 44.58]
# 17  <b>We believe that a customer’s decision to pu...   [4.25, 92.17, 3.59]
# 18  <b>As a manufacturer, our commitment to sustai...  [0.84, 10.28, 88.88]
# 19  <b>Several states in which we currently operat...   [2.53, 93.15, 4.32]
#
#    E_finBERT_maxSentiment E_fineTuned_ntl_pos_neg E_fineTuned_maxSentiment  \
# 0                 neutral     [0.27, 0.15, 99.58]                 negative
# 1                positive     [0.23, 60.9, 38.87]                 positive
# 2                negative     [0.07, 99.91, 0.02]                 positive
# 3                negative      [0.2, 99.76, 0.05]                 positive
# 4                positive     [93.77, 0.04, 6.19]                  neutral
# 5                 neutral    [9.41, 11.71, 78.88]                 negative
# 6                positive      [99.9, 0.06, 0.04]                  neutral
# 7                positive      [95.5, 0.08, 4.41]                  neutral
# 8                negative     [0.63, 99.34, 0.03]                 positive
# 9                negative     [0.34, 99.62, 0.04]                 positive
# 10                neutral     [0.39, 4.82, 94.79]                 negative
# 11               positive     [3.39, 0.09, 96.52]                 negative
# 12               negative     [0.04, 99.94, 0.02]                 positive
# 13                neutral       [3.6, 0.2, 96.21]                 negative
# 14               positive     [99.23, 0.02, 0.75]                  neutral
# 15               positive     [99.96, 0.01, 0.03]                  neutral
# 16               positive     [0.05, 99.93, 0.02]                 positive
# 17               positive    [28.28, 70.99, 0.73]                 positive
# 18               negative     [0.04, 99.94, 0.02]                 positive
# 19               positive     [99.98, 0.01, 0.01]                  neutral
#
#     E_twitter_ntl_pos_neg E_twitter_maxSentiment vote_balanced vote_extreme  \
# 0    [33.53, 3.21, 63.26]               negative      negative     negative
# 1   [57.98, 12.17, 29.85]                neutral      positive     positive
# 2    [29.18, 68.17, 2.65]               positive      positive     positive
# 3    [25.92, 3.48, 70.61]               negative      negative     negative
# 4    [57.22, 9.57, 33.21]                neutral       neutral      neutral
# 5   [54.91, 20.37, 24.72]                neutral       neutral      neutral
# 6   [74.95, 10.19, 14.86]                neutral       neutral      neutral
# 7    [74.01, 19.75, 6.24]                neutral       neutral      neutral
# 8     [8.83, 91.02, 0.15]               positive      positive     positive
# 9     [10.34, 89.5, 0.17]               positive      positive     positive
# 10    [42.92, 5.0, 52.08]               negative      negative     negative
# 11   [40.73, 2.24, 57.03]               negative      negative     negative
# 12   [35.74, 61.73, 2.53]               positive      positive     positive
# 13   [34.06, 1.87, 64.08]               negative      negative     negative
# 14   [56.74, 4.28, 38.98]                neutral       neutral      neutral
# 15   [64.63, 6.85, 28.52]                neutral       neutral      neutral
# 16   [48.24, 50.39, 1.37]               positive      positive     positive
# 17   [51.96, 5.67, 42.37]                neutral      positive     positive
# 18   [15.93, 83.66, 0.41]               positive      positive     positive
# 19    [58.52, 5.58, 35.9]                neutral       neutral      neutral
#
#    vote_annuled
# 0      negative
# 1      positive
# 2      positive
# 3      negative
# 4       neutral
# 5       neutral
# 6       neutral
# 7       neutral
# 8      positive
# 9      positive
# 10     negative
# 11     negative
# 12     positive
# 13     negative
# 14      neutral
# 15      neutral
# 16     positive
# 17     positive
# 18     positive
# 19      neutral
# DF_S:
# 	 LEN 4
# 	 POS 3
# 	 NEG 0
# 	 NTL 1
#                                                QUERY  MATCH_SCORE  PRG_NUM  \
# 0  Social. Community. Human rights. Product respo...        80.86       87
# 1  Social. Community. Human rights. Product respo...        80.62      857
# 2  Social. Community. Human rights. Product respo...        80.40       65
# 3  Social. Community. Human rights. Product respo...        80.06       96
#
#                                              PRG_TXT  \
# 0  In order to attract and retain our employees, ...
# 1  OBLIGATIONS OF THE PARTIES OBLIGATIONS OF THE ...
# 2  As a manufacturer, our commitment to sustainab...
# 3  The success of our business is fundamentally c...
#
#                                             filtered  \
# 0  ['In order to attract and retain our employees...
# 1  ['OBLIGATIONS OF THE PARTIES OBLIGATIONS OF TH...
# 2  ['We endeavor to consistently increase our sup...
# 3  ['We provide our employees and their families ...
#
#                                            FORMATTED S_finBERT_ntl_pos_neg  \
# 0  <b>In order to attract and retain our employee...    [1.0, 30.71, 68.3]
# 1  <b>OBLIGATIONS OF THE PARTIES OBLIGATIONS OF T...   [2.62, 93.97, 3.42]
# 2  <b>As a manufacturer, our commitment to sustai...  [0.84, 10.28, 88.88]
# 3  The success of our business is fundamentally c...  [1.13, 60.88, 37.99]
#
#   S_finBERT_maxSentiment S_fineTuned_ntl_pos_neg S_fineTuned_maxSentiment  \
# 0               negative      [0.08, 99.9, 0.02]                 positive
# 1               positive     [99.99, 0.01, 0.01]                  neutral
# 2               negative     [0.04, 99.94, 0.02]                 positive
# 3               positive     [99.68, 0.31, 0.01]                  neutral
#
#   S_twitter_ntl_pos_neg S_twitter_maxSentiment vote_balanced vote_extreme  \
# 0   [5.31, 94.54, 0.14]               positive      positive     positive
# 1   [81.9, 14.94, 3.16]                neutral       neutral      neutral
# 2  [15.93, 83.66, 0.41]               positive      positive     positive
# 3   [7.39, 92.47, 0.14]               positive      positive     positive
#
#   vote_annuled
# 0     positive
# 1      neutral
# 2     positive
# 3     positive
# DF_G:
# 	 LEN 0
# 	 POS 0
# 	 NEG 0
# 	 NTL 0
# Empty DataFrame
# Columns: [QUERY, MATCH_SCORE, PRG_NUM, PRG_TXT, filtered, FORMATTED, G_finBERT_ntl_pos_neg, G_finBERT_maxSentiment, G_fineTuned_ntl_pos_neg, G_fineTuned_maxSentiment, G_twitter_ntl_pos_neg, G_twitter_maxSentiment, vote_balanced, vote_extreme, vote_annuled]
# Index: []
